# %%
# notebook import

from ipynb.fs.full.data_processing import *

# %%
# user input parameters

# boolean parameter to dictate whether code is run
run = True

# boolean parameter to dictate use of print statements
debug = True

# boolean parameter to dictate whether results are written to .csv files
write = True

# %%
# function declaration

# input: series of measurements (ser)
# output: gini index for the series of measurements
def gini_coefficient_fn(ser):
    total = 0
    for i, xi in enumerate(ser[:-1], 1):
        total += np.sum(np.abs(xi - ser[i:]))
    return total / (len(ser)**2 * np.mean(ser))

# %%
# `main()` function declaration

# intended use in coordination with `gini_index_plot.ipynb`
# requires: import of `data_processing.ipynb` and user input parameters specified above
# output: None (assigns new global variable `pairwise_dict` and writes to specified output .csv files)

def main():
    
    # dictionary mapping each feature to each well and its corresponding entropy through time
    global gini_dict 
    gini_dict = {}
    
    for ref, name in zip(feature_ref_list, feature_name_list):
        
        # create dictionary mapping each feature to a dictionary of wells 
        gini_dict[name] = {}
        
        for well in experiment_dict:
            
            if write:
                csv_fpath = results_fpath + gini_ext + f'{name}_{well}_gini_list.csv'
                append_row_csv(csv_fpath, ['gini'])
            
            well_df = experiment_dict[well]
            gini_dict[name][well] = []
            
            for t in timestep_list:
                
                # calculate entropy at each time step, appending to running list 
                ser = well_df.loc[well_df[timestep_ref] == t][ref]
                g = gini_coefficient_fn(ser)
                gini_dict[name][well].append(g)  
                
                # write
                if write:
                    append_row_csv(csv_fpath, [g])
    
    if debug:
        print('gini_dict:', type(gini_dict), '\n', gini_dict)
        
    return

# %%
# call to `main()` function

if run:
    main()
# Out:
# gini_dict: <class 'dict'>
#  {'gfp': {'01': [0.18861463841223947, 0.12287216885242316, 0.11749172028051101, 0.16462116009960912, 0.1622100207285631, 0.11377859813768436, 0.14926305200568585, 0.14909298459414874, 0.17117179687307799, 0.14600935714706328, 0.14499202718825555, 0.12960690178387135, 0.09297718862711123, 0.06821187892590462, 0.06631738015329598, 0.073830215093953, 0.07286635979598552, 0.0882299520717181, 0.04418852307829269, 0.10808303600811353, 0.09401946442378549, 0.0922390054165846, 0.06503942912184317, 0.06467818748378236, 0.040319500709371736, 0.043052070604465115, 0.04020093488675077, 0.04073521514222042, 0.035867912475791505, 0.02997652140942043, 0.03607590548504934, 0.03492354165172792, 0.06417647969655382, 0.04072225347592848, 0.03812843371935228, 0.042556533425752045, 0.04839130385957046, 0.04004450611931579, 0.05001600403370213, 0.051133321368999764, 0.03911867171611707, 0.034743744601073316, 0.03952461934393464, 0.032446051295830156, 0.04166183895542534, 0.0389218146352152, 0.03458350101679342, 0.038206347165116505, 0.0397485068386059, 0.03453340272826152, 0.039768608178291406, 0.040122710497536435, 0.04020830594079292, 0.03684500385415029, 0.038190835920159406, 0.044281605763520866, 0.04629284355541419, 0.04205434510397491, 0.044047062999647196, 0.03235808390132612, 0.046547154048795905, 0.04938596286383507, 0.050736490522368866, 0.041190746345557014, 0.05089921313373686, 0.05146938157013297, 0.04393823821785, 0.04077463333258659, 0.04615869464229309, 0.04442973070821679, 0.035831529971695315, 0.04151584723218089, 0.0403506196296638, 0.03889489483603258, 0.0422619694976476, 0.03645723656268872, 0.03783567483672007, 0.03490157314521738, 0.040865678156780216, 0.046373834354523254, 0.039080991167086354, 0.04770785680393441, 0.04854736699017513, 0.03926029871153964, 0.04951568159042247, 0.03785006724404943, 0.037780403348920064, 0.04544379186199884, 0.04570719657200341, 0.0441450448062902, 0.043727430451190756, 0.04025653098983626, 0.04544437657982327, 0.054127210254097016, 0.03915700715529215, 0.041982194807297965, 0.049162873699267653, 0.03508926621829859, 0.03612628228032725, 0.036026196062056454, 0.036677843283904846, 0.03173453144561349, 0.039258117820679575, 0.03828752839802989, 0.03661899105525951, 0.03808160388824314, 0.0419600939003332, 0.04366427229482822, 0.042411562991738865, 0.036284417085161155, 0.037249107934350593, 0.03893197253899896, 0.041273007788262844, 0.03901048466542828, 0.03580421289870528, 0.0393022538591486, 0.04212510329031348, 0.0372778382753418, 0.04006750269162506, 0.037189020023322736, 0.038963995992992356, 0.04005798259337894, 0.03528889129127638, 0.037368868945403304, 0.03988654649559116, 0.039414868247979414, 0.04064152114836389, 0.04692181966676919, 0.04391538336860187, 0.04721876743614611, 0.0443944243084015, 0.051014141261696413, 0.03758574737167355, 0.04553027424357563, 0.0483836893906014, 0.04732974447517497, 0.04431149172645037, 0.04405306529035704, 0.0480430256853426, 0.04644459890601695, 0.0545117135641315, 0.05141791489412023, 0.05879499827142213, 0.06256975858206872, 0.050192403027026274, 0.05296917741950135, 0.052002711884503644, 0.05266237620835505, 0.05455880268824376, 0.04975334520010042, 0.05499365162502758, 0.05799389622988194, 0.05519711895412683, 0.05173057550311121, 0.05195771951269206, 0.0642358257222168, 0.06480106321882914, 0.06402175992950435, 0.06285703578116508, 0.06250879272381739, 0.07014031820263922, 0.08767564637993079, 0.07776653259320788, 0.07019754186469018, 0.0520021204524155, 0.050320217609343965, 0.049802131311831484, 0.05327230277409398, 0.056377000036096366, 0.061348961346439315, 0.047312484123728384, 0.05581359647680282, 0.05925617260255266, 0.06797987678926429, 0.05571995176645896, 0.05602127635516445, 0.06185584127748204, 0.06344991548127718, 0.06410220635689272, 0.057183109118694675, 0.05471482609222693, 0.059147740060573606, 0.059724315514109165, 0.05694588153306901, 0.05830626967152538, 0.06230664986079167, 0.060165426734701356, 0.05915018214612481, 0.0659701 ...
