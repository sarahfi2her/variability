# %%
import warnings
warnings.simplefilter("ignore", FutureWarning)

# %%
import matplotlib.pyplot as plt
import os, sys
import numpy as np
from PIL import Image
import cv2

import pandas as pd
import seaborn as sns
from scipy import stats

import json
import ujson
from datetime import datetime, timedelta
from scipy.stats import entropy
import matplotlib.dates as mdates
import kneed
from kneed import DataGenerator, KneeLocator
DEBUG = False

import os
import glob

# %%
def entropy_full_sup(color,min_color, max_color, i):
    color= pd.Series(color)
    s = color.value_counts(bins = np.linspace(min_color,max_color,i))
    return entropy(s, base=2)

# %%
def entropy_curve(color):
    x = [5,10,20,30,50,75,100,200,300,400,500,1000,1500,2000,2500,5000,10000]
    sns.histplot(color)
    plt.show()
    plt.close()
    Entropy_val =[]
    
    for i in x:
        val = entropy_full_sup(color,color.min(),color.max(), i)
        print(val)
    
        Entropy_val.append(val)
    y = Entropy_val
    kneedle = kneed.KneeLocator(x,y , S=1, curve="concave", direction="increasing")
    knee_point = kneedle.knee #elbow_point = kneedle.elbow
    print('Knee: ', knee_point) #print('Elbow: ', elbow_point)

    # Plot the data and the knee
    plt.plot(x, y, '-o')
    plt.axvline(knee_point, color='red', linestyle='--')
    plt.show()
    values_Entorpy = [color.min(),color.max(),knee_point]
    print(values_Entorpy)
    return values_Entorpy

# %%
import glob
import pandas as pd


path = r'H:\\230124\\'

# Get a list of all the CSV files in the directory
csv_files = glob.glob(path + '**/Time_points_dfs_*.csv', recursive=True)

# Create an empty dictionary to store the DataFrames
dfs = {}

# Loop through each CSV file
for file in csv_files:
    # Split the file name to get the number
    number = file.split('_')[-1].split('.')[0]
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file)
    # If the number is not already in the dictionary, add it
    if number not in dfs:
        dfs[number] = df
    # If the number is already in the dictionary, concatenate the DataFrames
    else:
        dfs[number] = pd.concat([dfs[number], df], axis=0, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       5 path = r'H:\\230124\\'
#       7 # Get a list of all the CSV files in the directory
# ----> 8 csv_files = glob.glob(path + '**/Time_points_dfs_*.csv', recursive=True)
#      10 # Create an empty dictionary to store the DataFrames
#      11 dfs = {}
#
# File ~\anaconda3\envs\cellpose\lib\glob.py:22, in glob(pathname, recursive)
#      11 def glob(pathname, *, recursive=False):
#      12     """Return a list of paths matching a pathname pattern.
#      13
#      14     The pattern may contain simple shell-style wildcards a la
#    (...)
#      20     zero or more directories and subdirectories.
#      21     """
# ---> 22     return list(iglob(pathname, recursive=recursive))
#
# File ~\anaconda3\envs\cellpose\lib\glob.py:75, in _iglob(pathname, recursive, dironly)
#      73     glob_in_dir = _glob0
#      74 for dirname in dirs:
# ---> 75     for name in glob_in_dir(dirname, basename, dironly):
#      76         yield os.path.join(dirname, name)
#
# File ~\anaconda3\envs\cellpose\lib\glob.py:83, in _glob1(dirname, pattern, dironly)
#      82 def _glob1(dirname, pattern, dironly):
# ---> 83     names = _listdir(dirname, dironly)
#      84     if not _ishidden(pattern):
#      85         names = (x for x in names if not _ishidden(x))
#
# File ~\anaconda3\envs\cellpose\lib\glob.py:136, in _listdir(dirname, dironly)
#     134 def _listdir(dirname, dironly):
#     135     with contextlib.closing(_iterdir(dirname, dironly)) as it:
# --> 136         return list(it)
#
# File ~\anaconda3\envs\cellpose\lib\glob.py:126, in _iterdir(dirname, dironly)
#     124 with os.scandir(dirname) as it:
#     125     for entry in it:
# --> 126         try:
#     127             if not dironly or entry.is_dir():
#     128                 yield entry.name
#
# KeyboardInterrupt:

# %%
# create a list to store the JSON files
json_files = []

pathes = [r'E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\']

for p in pathes:
    # set the path for the folder that contains the JSON files
    path = p

    # loop through the folder and add every 60th JSON file to the list
    for i, filename in enumerate(os.listdir(path)):
        if filename.endswith('.json') and (i+1) % 600 == 0:
            json_files.append(os.path.join(path, filename))

    # loop through the list and load each
    
data = pd.DataFrame()


for f_name in json_files:
    num = f_name.split('-')
    print(f_name)
    df = pd.read_json(f_name, lines=True)
    data = data.append(df)

# data = data.drop('Date',axis=1)
data = data.reset_index(drop=True)
# data = data.astype(float)
# Out:
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-182430.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-183433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-184433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-185433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-190433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-191433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-192433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-193433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-194433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-195433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-200433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-201433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-202433.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-203436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-204436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-205436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-210436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-211436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-212436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-213436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-214436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-215436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-220436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-221436.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-222440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-223440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-224440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-225440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-230440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-231440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-232440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-233440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-234440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230404-235440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-000440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-001440.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-002441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-003441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-004441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-005441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-010441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-011441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-012441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-013441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-014441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-015441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-020441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-021441.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-022442.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-023442.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-024442.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-025442.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-030442.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-031442.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-032450.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-033456.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-034605.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-035618.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-040644.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-041644.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-042646.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-043646.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-044646.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-045646.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-050646.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-051657.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-052657.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-053705.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-054705.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-055705.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-060716.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-061723.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-062728.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-063728.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-064728.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-065734.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-070734.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-071734.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-072740.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-073740.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-074747.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-075747.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-080747.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-081754.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-082754.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-083805.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-084805.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-085814.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-090814.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-091826.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-092826.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-093826.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-094826.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-095832.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-100832.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-101845.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-102851.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-103905.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-104914.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-105914.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-110914.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-111914.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-112914.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-113914.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-114914.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-115914.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-120914.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-121916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-122916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-123916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-124916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-125916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-130916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-131916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-132916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-133916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-134916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-135916.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-140920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-141920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-142920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-143920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-144920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-145920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-150920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-151920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-152920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-153920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-154920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-155920.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-160921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-161921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-162921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-163921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-164921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-165921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-170921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-171921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-172921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-173921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-174921.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-175924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-180924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-181924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-182924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-183924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-184924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-185924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-190924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-191924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-192924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-193924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-194924.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-195925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-200925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-201925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-202925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-203925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-204925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-205925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-210925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-211925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-212925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-213925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-214925.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-215928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-220928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-221928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-222928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-223928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-224928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-225928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-230928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-231928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-232928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-233928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-234928.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230405-235930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-000930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-001930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-002930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-003930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-004930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-005930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-010930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-011930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-012930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-013930.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-014931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-015931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-020931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-021931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-022931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-023931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-024931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-025931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-030931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-031931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-032931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-033931.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-034932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-035932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-040932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-041932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-042932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-043932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-044932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-045932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-050932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-051932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-052932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-053932.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-054934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-055934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-060934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-061934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-062934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-063934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-064934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-065934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-070934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-071934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-072934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-073934.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-074936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-075936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-080936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-081936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-082936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-083936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-084936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-085936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-090936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-091936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-092936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-093936.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-094938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-095938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-100938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-101938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-102938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-103938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-104938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-105938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-110938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-111938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-112938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-113938.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-114942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-115942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-120942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-121942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-122942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-123942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-124942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-125942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-130942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-131942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-132942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-133942.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-134943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-135943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-140943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-141943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-142943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-143943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-144943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-145943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-150943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-151943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-152943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-153943.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-154944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-155944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-160944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-161944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-162944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-163944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-164944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-165944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-170944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-171944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-172944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-173944.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-174947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-175947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-180947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-181947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-182947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-183947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-184947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-185947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-190947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-191947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-192947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-193947.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-194949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-195949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-200949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-201949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-202949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-203949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-204949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-205949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-210949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-211949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-212949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-213949.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-214951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-215951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-220951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-221951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-222951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-223951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-224951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-225951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-230951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-231951.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-232952.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-233954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-234954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230406-235954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-000954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-001954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-002954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-003954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-004954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-005954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-010954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-011954.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-012955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-013955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-014955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-015955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-020955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-021955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-022955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-023955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-024955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-025955.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-030956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-031956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-032956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-033956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-034956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-035956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-040956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-041956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-042956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-043956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-044956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-045956.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-050957.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-051957.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-052957.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-053957.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-054957.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-055957.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-060957.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-061957.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-062959.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-063959.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-064959.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-065959.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-070959.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-071959.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-073000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-074000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-075000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-080000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-081000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-082000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-083000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-084000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-085000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-090000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-091000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-092000.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-093007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-094007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-095007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-100007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-101007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-102007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-103007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-104007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-105007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-110007.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-111008.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-112009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-113009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-114009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-115009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-120009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-121009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-122009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-123009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-124009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-125009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-130009.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-131010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-132010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-133010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-134010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-135010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-140010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-141010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-142010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-143010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-144010.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-145013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-150013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-151013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-152013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-153013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-154013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-155013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-160013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-161013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-162013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-163013.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-164016.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-165018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-170018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-171018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-172018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-173018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-174018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-175018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-180018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-181018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-182018.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-183021.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-184023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-185023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-190023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-191023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-192023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-193023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-194023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-195023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-200023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-201023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-202023.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-203024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-204024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-205024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-210024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-211024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-212024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-213024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-214024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-215024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-220024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-221024.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-222028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-223028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-224028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-225028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-230028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-231028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-232028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-233028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-234028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230407-235028.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-000029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-001029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-002029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-003029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-004029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-005029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-010029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-011029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-012029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-013029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-014029.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-015030.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-020030.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-021032.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-022032.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-023032.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-024032.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-025032.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-030032.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-031032.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-032032.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-033034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-034034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-035034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-040034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-041034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-042034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-043034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-044034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-045034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-050034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-051034.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-052036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-053036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-054036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-055036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-060036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-061036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-062036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-063036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-064036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-065036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-070036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-071036.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-072038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-073038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-074038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-075038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-080038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-081038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-082038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-083038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-084038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-085038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-090038.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-091039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-092039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-093039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-094039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-095039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-100039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-101039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-102039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-103039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-104039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-105039.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-110040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-111040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-112040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-113040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-114040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-115040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-120040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-121040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-122040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-123040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-124040.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-125042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-130042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-131042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-132042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-133042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-134042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-135042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-140042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-141042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-142042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-143042.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-144047.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-145047.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-150047.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-151049.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-152049.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-153049.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-154049.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-155049.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-160049.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-161049.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-162050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-163050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-164050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-165050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-170050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-171050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-172050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-173050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-174050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-175050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-180050.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-181052.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-182052.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-183052.json
# E:\\Dropbox (Weizmann Institute)\\Time lapse\\2023040412\\20230408-184052.json

# %%
CSV_path =r'E:\\Dropbox (Weizmann Institute)\Time lapse\\CSV_FB_20230404\\'

# Create an empty dictionary to store the DataFrames
dfs = {}

extension = 'csv'
os.chdir(CSV_path)
result = glob.glob('*.{}'.format(extension))
    
for i in range(1,16):
    well = str(i).zfill(2)

    df = pd.read_csv('Time_points_dfs_'+well+'.csv')
    dfs[i] = df

# %%
# get Full support measuerments for GFP and RFP
for_entropy = pd.DataFrame(columns = ['Mean_GFP','Mean_RFP'])
for i in dfs:
    df = dfs[i]
    df_Short = pd.DataFrame()
    df_Short[['Mean_GFP','Mean_RFP']] = df[['mean_F_C2','mean_F_C3']]
    for_entropy = for_entropy.append(df_Short)

# %%
RFP_entropy_vals = entropy_curve(for_entropy['Mean_RFP'])
GFP_entropy_vals = entropy_curve(for_entropy['Mean_GFP'])
# Out:
# 0.08299386631668774
# 1.0418888459998819
# 1.7800407565279095
# 2.002266189123323
# 2.6622360641807905
# 3.224058870209196
# 3.6106948415474003
# 4.588829737080592
# 5.168354644593609
# 5.581633200653692
# 5.902883570175041
# 6.902059521340634
# 7.486777727118596
# 7.901489970056773
# 8.223249671750118
# 9.221636570128048
# 10.218528130881486
# Knee:  1500
# [169.5940170940171, 1408.4260504201682, 1500]
# 1.4147373296585808
# 2.0146542085637344
# 3.010993731050148
# 3.5630261705702413
# 4.2874613876445204
# 4.873923738828976
# 5.290614595437959
# 6.294390542643448
# 6.88091506227465
# 7.2968399628630305
# 7.619253339553744
# 8.620146676162028
# 9.20508867742908
# 9.619960910935452
# 9.941558141524299
# 10.93992951368596
# 11.936333489383678
# Knee:  1500
# [226.7664835164835, 2179.6913580246915, 1500]

# %%
# calculate entropy levels base on full support

for i in dfs:
    df = dfs[i]
    time = df['Time_Stamp'].unique()
    for t in time:
        rel_df = df[df['Time_Stamp']==t]
        entropy_val_GFP =  entropy_full_sup(rel_df['mean_F_C2'],GFP_entropy_vals[0],GFP_entropy_vals[1],GFP_entropy_vals[2])
        dfs[i].loc[dfs[i]['Time_Stamp']==t, 'GFP_entropy']=entropy_val_GFP
        entropy_val_RFP =  entropy_full_sup(rel_df['mean_F_C3'],RFP_entropy_vals[0],RFP_entropy_vals[1],RFP_entropy_vals[2])
        dfs[i].loc[dfs[i]['Time_Stamp']==t, 'RFP_entropy']=entropy_val_RFP
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 10
#       8 entropy_val_GFP =  entropy_full_sup(rel_df['mean_F_C2'],GFP_entropy_vals[0],GFP_entropy_vals[1],GFP_entropy_vals[2])
#       9 dfs[i].loc[dfs[i]['Time_Stamp']==t, 'GFP_entropy']=entropy_val_GFP
# ---> 10 entropy_val_RFP =  entropy_full_sup(rel_df['mean_F_C3'],RFP_entropy_vals[0],RFP_entropy_vals[1],RFP_entropy_vals[2])
#      11 dfs[i].loc[dfs[i]['Time_Stamp']==t, 'RFP_entropy']=entropy_val_RFP
#
# Cell In[11], line 8, in entropy_full_sup(color, min_color, max_color, i)
#       6 color = pd.Series(color)
#       7 s = color.value_counts(bins=np.linspace(min_color, max_color, i))
# ----> 8 return entropy(s, base=2)
#
# File ~\anaconda3\envs\cellpose\lib\site-packages\scipy\stats\_entropy.py:135, in entropy(pk, qk, base, axis)
#     132     raise ValueError("`base` must be a positive number or `None`.")
#     134 pk = np.asarray(pk)
# --> 135 pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
#     136 if qk is None:
#     137     vec = special.entr(pk)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
from scipy.stats import entropy

def entropy_full_sup(color, min_color, max_color, i):
    color = pd.Series(color)
    s = color.value_counts(bins=np.linspace(min_color, max_color, i))
    return entropy(s, base=2)

def calculate_entropies(group, min_max_vals):
    group['GFP_entropy'] = entropy_full_sup(group['mean_F_C2'], *min_max_vals['GFP'])
    group['RFP_entropy'] = entropy_full_sup(group['mean_F_C3'], *min_max_vals['RFP'])
    return group

min_max_vals = {
    'GFP': GFP_entropy_vals,
    'RFP': RFP_entropy_vals
}

for i in dfs:
    df = dfs[i]
    dfs[i] = df.groupby('Time_Stamp').apply(lambda group: calculate_entropies(group, min_max_vals))

# %%
# Plot a specific well
for i in range(1,16):
    Plot_well = dfs[i]
    Plot_well['Date_time'] = pd.to_datetime(Plot_well["Time_Stamp"], format='%Y%m%d-%H%M%S')

    import matplotlib.dates as mdates
    # Initialize figure and subplots
    fig, (axi, axii) = plt.subplots(1, 2, figsize=(16,5))


    # ax = sns.lineplot(x = 'Date_time', y = 'GFP_entropy', data = Plot_well, label = 'GFP_entropy', color = 'green')
    # ax = sns.lineplot(x = 'Date_time', y = 'RFP_entropy', data = Plot_well, label = 'RFP_entropy', color = 'red')
    axi = sns.lineplot(x = 'Date_time', y = 'mean_F_C2', data = Plot_well, label = 'Mean GFP', color = 'green',ax = axi )
    axi = sns.lineplot(x = 'Date_time', y = 'mean_F_C3', data = Plot_well, label = 'Mean RFP', color = 'red',ax = axi )

    # ax = sns.lineplot(x = 'Date_time', y = 'area', data = try_df)

    # Add the secondary y-axis on the right
    ax2 = axi.twinx()

    # Plot `data['T_CHIP(celcius)']` against the secondary y-axis
    sns.lineplot(x = data['Date'], y = data['T_CHIP(celcius)'], ax = ax2, color = 'orange', label = 'Temp in C',legend=False)


    axi.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    xticks = axi.get_xticklabels()
    plt.setp(xticks, rotation=45)

    axi.set_title("Mean experssion")
    # ax = sns.lineplot(x = 'Date_time', y = 'GFP_entropy', data = Plot_well, label = 'GFP_entropy', color = 'green')
    # ax = sns.lineplot(x = 'Date_time', y = 'RFP_entropy', data = Plot_well, label = 'RFP_entropy', color = 'red')
    axii = sns.lineplot(x = 'Date_time', y = 'GFP_entropy', data = Plot_well, label = 'Entropy GFP', color = 'green',ax = axii )
    axii = sns.lineplot(x = 'Date_time', y = 'RFP_entropy', data = Plot_well, label = 'Entropy RFP', color = 'red',ax = axii )

    # ax = sns.lineplot(x = 'Date_time', y = 'area', data = try_df)

    # Add the secondary y-axis on the right
    ax2i = axii.twinx()

    # Plot `data['T_CHIP(celcius)']` against the secondary y-axis
    sns.lineplot(x = data['Date'], y = data['T_CHIP(celcius)'], ax = ax2i, color = 'orange', label = 'Temp in C',legend=False)


    axii.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    xticks = axii.get_xticklabels()
    plt.setp(xticks, rotation=45)
    axii.set_title("Entropy")

    # # Format the x-axis as dates
    # lines1, labels1 = ax.get_legend_handles_labels()
    # lines2, labels2 = ax2.get_legend_handles_labels()
    # ax.legend(lines1 + lines2, labels1 + labels2, loc = 'upper left')

    plt.show()

# %%
convert -delay 20 -loop 0 image1.gif image2.mp4 output.gif
# Out:
# ERROR: Could not find a version that satisfies the requirement FFMpegWriter (from versions: none)
# ERROR: No matching distribution found for FFMpegWriter

# %%
import matplotlib as mpl 
mpl.rcParams['animation.ffmpeg_path'] = r'C:\\Users\\Maor\\anaconda3\\Lib\\site-packages\\imageio_ffmpeg\\binaries\\ffmpeg-win64-v4.2.2.exe'
# %matplotlib notebook

import matplotlib.pyplot as plt
import matplotlib.animation as animation


Plot_well = dfs['023']
Plot_well['Date_time'] = pd.to_datetime(Plot_well["Time_Stamp"], format='%Y%m%d-%H%M%S')

import matplotlib.dates as mdates

ax = sns.lineplot(x = 'Date_time', y = 'GFP_entropy', data = Plot_well, label = 'GFP_entropy', color = 'green')
ax = sns.lineplot(x = 'Date_time', y = 'RFP_entropy', data = Plot_well, label = 'RFP_entropy', color = 'red')
# ax = sns.lineplot(x = 'Date_time', y = 'Number_cells', data = Plot_well, label = 'Cell count', color = 'blue')
# ax = sns.lineplot(x = 'Date_time', y = 'area', data = try_df)

# Add the secondary y-axis on the right
ax2 = ax.twinx()

# Plot `data['T_CHIP(celcius)']` against the secondary y-axis
sns.lineplot(x = data['Date'], y = data['T_CHIP(celcius)'], ax = ax2, color = 'orange', label = 'Temp in C',legend=False)


ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=45)

line = plt.axvline(x=data['Date'].iloc[0], color='salmon')
x_timestamps = [mdates.date2num(d) for d in data['Date'].values]


def update(frame):
    line.set_xdata([frame, frame])

ani = animation.FuncAnimation(plt.gcf(), update, frames = x_timestamps, interval=0.01)

plt.show()

f = r"H://animation.gif" 
writergif = animation.PillowWriter(fps=30) 
ani.save(f, writer=writergif)

# f = r"H://animation.mp4"
# writervideo = animation.FFMpegWriter(fps=60)
# ani.save(f, writer=writervideo)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# !pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Using cached ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      -------------------------------------- 840.9/840.9 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: future
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492055 sha256=5a0a413d7e0a38413c5a8290ce4ba741f50ff5b91efe721b995c4fb0000b2f31
#   Stored in directory: c:\users\maor\appdata\local\pip\cache\wheels\0c\ff\54\efb16da5b1058114a457b3c7167904915d2e5764b637ae8d3d
# Successfully built future
# Installing collected packages: future, ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0 future-0.18.3

# %%
import os
import pandas as pd

root_dir = r'H:\\230124\\'
csv_dir = os.path.join(root_dir, "csv_for_MV")

# create a dictionary to store the filenames
data = {}

# iterate through all the sub-directories
for subdir, dirs, files in os.walk(root_dir):
    for file in files:
        # check if the file name matches the pattern and has z1 and c1 in the title
        if file.endswith(".tif") and "z1" in file and "c1" in file:
            xy = file.split("xy")[1][:3]
            if xy not in data:
                data[xy] = []
            data[xy].append(os.path.join(subdir, file))

# sort the filenames by creation time
for xy in data:
    data[xy].sort(key=lambda x: os.path.getctime(x))

# create the csv folder if it doesn't exist
if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

# create a csv file for each xy number
for xy in data:
    df = pd.DataFrame({"file_name": data[xy]})
    df.to_csv(os.path.join(csv_dir, f"{xy}.csv"), index=False)
